# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_excel("세대원수별+세대수_20230320092915.xlsx")
# Out:
# C:\Users\cksgh\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#     동별(1)  동별(2)  동별(3)     2021   2021.1  2021.2  2021.3  2021.4  2021.5  \
# 0   동별(1)  동별(2)  동별(3)     전체세대     1인세대    2인세대    3인세대    4인세대    5인세대
# 1      합계     소계     소계  4426007  1906690  978393  750762  616312  135649
# 2     NaN    강서구     소계   271175   118270   61743   45135   35921    8003
# 3     NaN    NaN    염창동    16309     4712    3314    3769    3736     653
# 4     NaN    NaN   등촌1동    13600     7895    2598    1642    1180     226
# 5     NaN    NaN   등촌2동     8668     2979    2138    1753    1350     335
# 6     NaN    NaN   등촌3동    15012     6584    3926    2397    1718     304
# 7     NaN    NaN   화곡본동    17267     8414    3892    2565    1849     439
# 8     NaN    NaN   화곡2동     8187     3190    2131    1495    1030     282
# 9     NaN    NaN   화곡3동     9657     3758    2342    1730    1378     340
# 10    NaN    NaN   화곡4동     9748     4008    2575    1713    1122     256
# 11    NaN    NaN   화곡6동    12586     6347    2582    1875    1388     297
# ...

# %%
df1=df.copy()
df1=df1.drop(1,axis=0)
df1=df1.drop('동별(1)', axis=1)
df1['동별(2)'] = '강서구'
df1.replace("-", 0,inplace=True)
df1_2021 = df1.iloc[:,0:13]
df1_2022 = df1.iloc[:,[0,1]+list(range(13,len(df1.columns)))]

# %%
df1_2021.columns = df1_2021.loc[0]
df1_2021=df1_2021.drop(0,axis=0)
df1_2022.columns = df1_2022.loc[0]
df1_2022=df1_2022.drop(0,axis=0)

# %%
df1_2021.columns = [df1_2021.columns[0],'동별']+[x for x in df1_2021.columns[2:]]
df1_2022.columns = [df1_2022.columns[0],'동별']+[x for x in df1_2022.columns[2:]]

# %%
df1_2021=df1_2021.drop(2, axis=0)

# %%
df1_2021=df1_2021.drop('전체세대',axis=1)

# %%
a=df1_2021['1인세대']+2*df1_2021['2인세대']+3*df1_2021['3인세대']+4*df1_2021['4인세대']+5*df1_2021['5인세대']+6*df1_2021['6인세대']+7*df1_2021['7인세대']+8*df1_2021['8인세대']+9*df1_2021['9인세대']+10*df1_2021['10인세대 이상']
df1_2021['총합']=a

# %%
df1_2021=df1_2021.drop(['강서구','1인세대','2인세대'
                        ,'3인세대','4인세대','5인세대','6인세대','7인세대','8인세대','9인세대','10인세대 이상'],axis=1)

# %%
df1_2021.columns=['동별','2021년도 인구총합']

# %%
df1_2022=df1_2022.drop(2, axis=0)
df1_2022=df1_2022.drop('전체세대',axis=1)
b=df1_2022['1인세대']+2*df1_2022['2인세대']+3*df1_2022['3인세대']+4*df1_2022['4인세대']+5*df1_2022['5인세대']+6*df1_2022['6인세대']+7*df1_2022['7인세대']+8*df1_2022['8인세대']+9*df1_2022['9인세대']+10*df1_2022['10인세대 이상']
df1_2022['총합']=b

# %% [markdown]
# ## 세대 기준이라 걍 곱해서 전부다 더해서 전체 합 구했음

# %%
df1_2022=df1_2022.drop(['강서구','1인세대','2인세대'
                        ,'3인세대','4인세대','5인세대','6인세대','7인세대','8인세대','9인세대','10인세대 이상'],axis=1)

# %%
df1_2022.columns=['동별1','2022년도 인구총합']

# %%
train = pd.concat([df1_2021,df1_2022],axis=1)
train= train.drop('동별1',axis=1)

# %%
train.head()
# Out:
#      동별 2021년도 인구총합 2022년도 인구총합
# 3   염창동       41637       41506
# 4  등촌1동       24239       24762
# 5  등촌2동       20303       19738
# 6  등촌3동       30544       29854
# 7  화곡본동       34181       33713

# %%
train.to_csv("인구 전체 총합")

# %%
train.sum()
# Out:
# 동별              염창동등촌1동등촌2동등촌3동화곡본동화곡2동화곡3동화곡4동화곡6동화곡8동가양1동가양2...
# 2021년도 인구총합                                                271175
# 2022년도 인구 총합                                               273697
# dtype: object
